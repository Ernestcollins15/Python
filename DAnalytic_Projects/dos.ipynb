# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x=np.array([0,6])
y=np.array([10,50])
plt.plot(x,y,marker='x')
plt.show()

# %%
ypoints =np.array([3,5,4,9])
plt.plot(ypoints,marker='x')
plt.show()

# %%
x1=np.array([0,2,3,5,7])
y1=np.array([4,7,8,9,5])
x2=np.array([1,6,8,9,10])
y2=np.array([3,4,6,6,8])
plt.plot(x1,y1,x2,y2,marker='o')
plt.show()

# %%
df=pd.read_csv(r"C:\Users\Ernest\Desktop\samples\datasets\travel_insurance.csv")
df
# Out:
#       Agency    Agency Type Distribution Channel  \
# 0        CBH  Travel Agency              Offline
# 1        CBH  Travel Agency              Offline
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# 5        JZI       Airlines               Online
# 6        CWT  Travel Agency               Online
# 7        CWT  Travel Agency               Online
# 8        CWT  Travel Agency               Online
# 9        CWT  Travel Agency               Online
# 10       JZI       Airlines               Online
# 11       JZI       Airlines               Online
# 12       KML  Travel Agency               Online
# 13       CWT  Travel Agency               Online
# 14       EPX  Travel Agency               Online
# 15       CWT  Travel Agency               Online
# 16       CWT  Travel Agency               Online
# 17       CWT  Travel Agency               Online
# ...

# %%
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value) Gender  Age  \
# 0    No       186    MALAYSIA      -29.0                  9.57      F   81
# 1    No       186    MALAYSIA      -29.0                  9.57      F   71
# 2    No        65   AUSTRALIA      -49.5                 29.70      M   32
# 3    No        60   AUSTRALIA      -39.6                 23.76      M   32
# 4    No        79       ITALY      -19.8                 11.88      M   41
#
#           timestamp
# 0  25/06/2022 18:19
# ...

# %%
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value) Gender  Age  \
# 0    No       186    MALAYSIA      -29.0                  9.57      F   81
# 1    No       186    MALAYSIA      -29.0                  9.57      F   71
# 2    No        65   AUSTRALIA      -49.5                 29.70      M   32
# 3    No        60   AUSTRALIA      -39.6                 23.76      M   32
# 4    No        79       ITALY      -19.8                 11.88      M   41
#
#           timestamp
# 0  25/06/2022 18:19
# ...

# %% [markdown]
# df.tail()

# %%
   df.describe().T
# Out:
#                         count       mean         std    min   25%    50%  \
# Duration              63326.0  49.317074  101.791566   -2.0   9.0  22.00
# Net Sales             63326.0  40.702018   48.845637 -389.0  18.0  26.53
# Commision (in value)  63326.0   9.809992   19.804388    0.0   0.0   0.00
# Age                   63326.0  39.969981   14.017010    0.0  35.0  36.00
#
#                         75%     max
# Duration              53.00  4881.0
# Net Sales             48.00   810.0
# Commision (in value)  11.55   283.5
# Age                   43.00   118.0

# %%
df.columns
# Out:
# Index(['Agency', 'Agency Type', 'Distribution Channel', 'Product Name',
#        'Claim', 'Duration', 'Destination', 'Net Sales', 'Commision (in value)',
#        'Gender', 'Age', 'timestamp'],
#       dtype='object')

# %%
df1=df.drop(df.columns[[0,2]],axis=1)
df1
# Out:
#          Agency Type                     Product Name Claim  Duration  \
# 0      Travel Agency               Comprehensive Plan    No       186
# 1      Travel Agency               Comprehensive Plan    No       186
# 2      Travel Agency  Rental Vehicle Excess Insurance    No        65
# 3      Travel Agency  Rental Vehicle Excess Insurance    No        60
# 4      Travel Agency  Rental Vehicle Excess Insurance    No        79
# 5           Airlines                       Value Plan    No        66
# 6      Travel Agency  Rental Vehicle Excess Insurance    No        47
# 7      Travel Agency  Rental Vehicle Excess Insurance    No        63
# 8      Travel Agency  Rental Vehicle Excess Insurance    No        57
# 9      Travel Agency  Rental Vehicle Excess Insurance    No       186
# 10          Airlines                       Basic Plan    No        33
# 11          Airlines                       Basic Plan    No         1
# ...

# %%
x=df['Age'].values
x
y=df['Net Sales'].values
y
i=pd.DataFrame(y,x)
i.head()
# Out:
#        0
# 81 -29.0
# 71 -29.0
# 32 -49.5
# 32 -39.6
# 41 -19.8

# %%
df.shape
# Out:
# (63326, 12)

# %%
df['Destination'].value_counts() #frequecy table
# Out:
# SINGAPORE                                 13255
# MALAYSIA                                   5930
# THAILAND                                   5894
# CHINA                                      4796
# AUSTRALIA                                  3694
# INDONESIA                                  3452
# UNITED STATES                              2530
# PHILIPPINES                                2490
# HONG KONG                                  2411
# INDIA                                      2251
# JAPAN                                      2061
# VIET NAM                                   1669
# KOREA, REPUBLIC OF                         1479
# UNITED KINGDOM                             1309
# TAIWAN, PROVINCE OF CHINA                  1090
# MYANMAR                                     806
# BRUNEI DARUSSALAM                           780
# NEW ZEALAND                                 537
# CANADA                                      528
# CAMBODIA                                    493
# ...

# %%
df['Net Sales'].hist(bins=50)

# %%
df.boxplot('Net Sales','Claim')

# %%
ax=sns.heatmap(df.corr(),cmap=sns.cubehelix_palette(20,light=0.95,dark=0.15))
ax

# %%
df.isnull().sum()
# Out:
# Agency                  0
# Agency Type             0
# Distribution Channel    0
# Product Name            0
# Claim                   0
# Duration                0
# Destination             0
# Net Sales               0
# Commision (in value)    0
# Gender                  0
# Age                     0
# timestamp               0
# dtype: int64

# %%
# Boston housing 
fdi=pd.read_csv(r"C:\Users\Ernest\Desktop\FDI_data.csv")
fdi
# Out:
#             Colour by Colour by sheet swap   Colour by title  \
# 0               Solar       Project sector  recipient sector
# 1         Small Hydro       Project sector  recipient sector
# 2            Biofuels       Project sector  recipient sector
# 3            Biofuels       Project sector  recipient sector
# 4               Solar       Project sector  recipient sector
# 5               Solar       Project sector  recipient sector
# 6     Biomass & Waste       Project sector  recipient sector
# 7               Solar       Project sector  recipient sector
# 8     Biomass & Waste       Project sector  recipient sector
# 9               Solar       Project sector  recipient sector
# 10    Biomass & Waste       Project sector  recipient sector
# 11    Biomass & Waste       Project sector  recipient sector
# 12              Solar       Project sector  recipient sector
# 13              Solar       Project sector  recipient sector
# ...

# %%
fdi.columns
# Out:
# Index(['Colour by', 'Colour by sheet swap', 'Colour by title',
#        'Inv. country vs proj. country', 'Investing entity',
#        'Investing entity title', 'Investment - Closing Y (filter)',
#        'Investment - Closing Year', 'Investor - Asset class',
#        'Investor - Category', 'Investor - Country', 'Investor - Country (Top)',
#        'Investor - OECD/non-OECD', 'Investor - Region', 'Last update',
#        'Project - Country (top)', 'Project - OECD/non-OECD',
#        'Project - Region', 'Receiving entity', 'Receiving entity title',
#        'Recipient - Country', 'Recipient - Sector', 'Investment ($bn)',
#        'Investment - Value $m', 'Number of Records'],
#       dtype='object')

# %%
fdi.isnull().sum()
# Out:
# Colour by                          0
# Colour by sheet swap               0
# Colour by title                    0
# Inv. country vs proj. country      0
# Investing entity                   0
# Investing entity title             0
# Investment - Closing Y (filter)    0
# Investment - Closing Year          0
# Investor - Asset class             0
# Investor - Category                0
# Investor - Country                 0
# Investor - Country (Top)           0
# Investor - OECD/non-OECD           0
# Investor - Region                  0
# Last update                        0
# Project - Country (top)            0
# Project - OECD/non-OECD            0
# Project - Region                   0
# Receiving entity                   0
# Receiving entity title             0
# Recipient - Country                0
# Recipient - Sector                 0
# Investment ($bn)                   0
# Investment - Value $m              0
# Number of Records                  0
# dtype: int64

# %%
fdi.head()
# Out:
#      Colour by Colour by sheet swap   Colour by title  \
# 0        Solar       Project sector  recipient sector
# 1  Small Hydro       Project sector  recipient sector
# 2     Biofuels       Project sector  recipient sector
# 3     Biofuels       Project sector  recipient sector
# 4        Solar       Project sector  recipient sector
#
#    Inv. country vs proj. country Investing entity Investing entity title  \
# 0                          False         Thailand              countries
# 1                          False         Thailand              countries
# 2                          False            India              countries
# 3                          False            India              countries
# 4                          False            China              countries
#
#    Investment - Closing Y (filter)  Investment - Closing Year  \
# 0                             2018                       2018
# 1                             2012                       2012
# ...

# %%
boston.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
fdi=fdi.drop(fdi.columns[[-1]],axis=1)
fdi.head()
# Out:
#      Colour by Colour by sheet swap   Colour by title  \
# 0        Solar       Project sector  recipient sector
# 1  Small Hydro       Project sector  recipient sector
# 2     Biofuels       Project sector  recipient sector
# 3     Biofuels       Project sector  recipient sector
# 4        Solar       Project sector  recipient sector
#
#    Inv. country vs proj. country Investing entity  Investment - Closing Year  \
# 0                          False         Thailand                       2018
# 1                          False         Thailand                       2012
# 2                          False            India                       2009
# 3                          False            India                       2009
# 4                          False            China                       2015
#
#   Investor - Asset class Investor - Category Investor - Country  \
# 0                     LL     Commercial bank           Thailand
# ...

# %%
fdi.corr()
# Out:
#                                Inv. country vs proj. country  \
# Inv. country vs proj. country                            NaN
# Investment - Closing Year                                NaN
#
#                                Investment - Closing Year
# Inv. country vs proj. country                        NaN
# Investment - Closing Year                            1.0

# %%
sns.pairplot(fdi.corr())
# Out:
# C:\Users\Ernest\Anaconda3\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# C:\Users\Ernest\Anaconda3\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-819c8400f999> in <module>()
# ----> 1 sns.pairplot(fdi.corr())
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
#    2108         elif diag_kind == "kde":
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-814e33480101> in <module>()
# ----> 1 boston1=boston1.columns
#       2 boston1
#
# NameError: name 'boston1' is not defined

# %%
sns.heatmap(boston1.corr())
# Out:
# <AxesSubplot:>
